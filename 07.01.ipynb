# %% [markdown]
# <a href="https://colab.research.google.com/github/romashina/algebra/blob/main/07.01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Верно ли, что:
# - а. $–4 \notin \mathbb{N}; –4 \in \mathbb{Z}; –4 \in \mathbb{Q}$;
# - б. 5,6 \notin \mathbb{N}; 5,6 \in \mathbb{Z}; 5,6 \in \mathbb{Q};
# - в. 28 \in \mathbb{N}; 28 \in \mathbb{Z}; 28 \in \mathbb{Q}?
#
# **Ответы**:
#
# - а. Верно
# - б. Неверно, не является целым 5,6 \notin \mathbb{Z}
# - в. Верно

# %% [markdown]
# 2. Какое из множеств (A или B) является подмножеством другого:
# - а. A — множество чётных чисел, B — множество чисел, кратных 4;
# - б. A — множество делителей числа 12, B — множество делителей числа 60;
# - в. A — множество треугольников, B — множество прямоугольных треугольников?
#
# **Ответы**:
#
# - а. $А \in {B}$
# - б. $А \in {B}$
# - в. $B \in {A}$

# %% [markdown]
# 3. Представьте в виде отношения целого числа к натуральному несколькими способами числа:
#
# - $1\frac{2}{5}$
# - $0.3$
# - $-3\frac{1}{4}$
# - $-27$
# - $0$
#
# **Ответы**:
#
# - $1\frac{2}{5} = \frac{7}{5} = \frac{14}{10}$
# - $0,3 = \frac{3}{10} = \frac{6}{20}$
# - $-3\frac{1}{4} = \frac{-13}{4} = \frac{-26}{8}$
# - $-27 = \frac{-27}{1} = \frac{-54}{2}$
# - $0 = \frac{0}{1} = \frac{0}{5}$

# %% [markdown]
# 4. Представьте в виде дроби с наименьшим натуральным знаменателем числа
#
# - $36 = \frac{36}{1}$
# - $-45 = \frac{-45}{1}$
# - $4,2 = \frac{21}{5}$
# - $-0,8 = \frac{-4}{5}$
# - $15\frac{1}{6} = \frac{91}{6}$
# - $ -\frac{2}{9}= \frac{-2}{9}$

# %% [markdown]
# 5. Представьте в виде бесконечной десятичной дроби число:
#
# - а. $\frac{1}{3}=0,(3)$
# - б. $\frac{5}{6}=0,8(3)$
# - в. $\frac{1}{7}=0,142857$
# - г. $-\frac{20}{9}=-2,(2)$
# - д. $-\frac{8}{15}=-0,5(3)$
# - е. $10,28=10,28(0)$
# - ж. $-17=-17,(0)$
# - з. $\frac{3}{16}=0,1875(0)$
# - и. $-1\frac{3}{40}=-1,075(0)$
# - к. $2\frac{7}{11}=2,(63)$

# %%
five=dict()
five['а']=1/3
five['б']=5/6
five['в']=1/7
five['г']=-20/9
five['д']=-8/15
five['е']=10.28
five['ж']=-17
five['з']=3/16
five['и']=-43/40
five['к']=29/11

for key, value in five.items():
    print(f"{key} = {value}")
# Out:
# а = 0.3333333333333333
# б = 0.8333333333333334
# в = 0.14285714285714285
# г = -2.2222222222222223
# д = -0.5333333333333333
# е = 10.28
# ж = -17
# з = 0.1875
# и = -1.075
# к = 2.6363636363636362

# %% [markdown]
# 6. Сравните рациональные числа:
#
# - а. $0,013 < 0,1004$
# - б. $-24 < 0,003$
# - в. $-3,24 > -3,42$
# - г. $\frac{3}{8} = 0,375$
# - д. $-1,174 > -1\frac{7}{40}$
# - е. $\frac{10}{11} < \frac{11}{12}$
# - ж. $-2,005 < 2,04$
# - з. $-1\frac{3}{4} = -1,75$
# - и. $0,437 < \frac{7}{16}$
# - к. $-\frac{1}{8} > -0,13$
# - л. $1,37 < 1,(37)$
# - м. $-5,(34) < -5,34$

# %%
six=dict()
six['а']=0.013 < 0.1004
six['б']=(-24) < 0.00
six['в']=(-3.24) > (-3.42)
six['г']=(3/8) == 0.375
six['д']=(-1.174) > (-47/40)
six['е']=10/11 < 11/12
six['ж']=(-2.005) < 2.04
six['з']=(-7/4) == -1.75
six['и']=0.437 < 7/16
six['к']=(-1/8) > (-0.13)
six['л']=1.37 < 1.373737
six['м']=(-5.343434) < (-5.34)

for key, value in six.items():
    print(f"{key} = {value}")
# Out:
# а = True
# б = True
# в = True
# г = True
# д = True
# е = True
# ж = True
# з = True
# и = True
# к = True
# л = True
# м = True
